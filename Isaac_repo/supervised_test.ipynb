# %%
import pandas as pd

# %%
# Attempting to bin timestamps into 2016 part buckets (14 days) with Failure 
master_df = pd.read_csv("../New+Master+Data+Set+-+EDPR.csv")
master_df.head()
# Out:
#   Turbine_ID    times_stamp  Gen_RPM_Max  Gen_RPM_Min  Gen_RPM_Avg  \
# 0        T11  1/1/2016 0:00       1339.4       1233.3       1270.9
# 1        T11  1/1/2016 0:10       1400.5       1239.8       1303.6
# 2        T11  1/1/2016 0:20       1423.6       1270.8       1344.3
# 3        T11  1/1/2016 0:30       1470.1       1258.7       1377.5
# 4        T06  1/1/2016 0:40       1302.7       1225.1       1257.6
#
#    Gen_RPM_Std  Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# 0         18.8                 42                   59                   61
# 1         40.2                 43                   59                   61
# 2         27.2                 43                   60                   61
# 3         48.9                 43                   60                   62
# 4         13.4                 41                   50                   50
#
#    Gen_Phase3_Temp_Avg  ...  Grd_Prod_VoltPhse3_Avg  Grd_Prod_CurPhse1_Avg  \
# 0                   60  ...                   398.0                  197.0
# 1                   60  ...                   397.9                  245.0
# 2                   61  ...                   397.3                  292.3
# 3                   61  ...                   397.0                  374.6
# 4                   51  ...                   395.6                  169.7
#
#    Grd_Prod_CurPhse2_Avg  Grd_Prod_CurPhse3_Avg  Grd_Prod_Pwr_Max  \
# 0                  234.1                  216.9             368.9
# 1                  283.3                  267.2             430.4
# 2                  331.9                  317.9             468.3
# 3                  414.7                  401.7             581.2
# 4                  201.5                  184.1             318.7
#
#    Grd_Busbar_Temp_Avg  Rtr_RPM_Std  Amb_WindSpeed_Est_Avg  \
# 0                   39          0.2                    5.4
# 1                   39          0.4                    5.8
# 2                   39          0.2                    6.1
# 3                   39          0.4                    6.5
# 4                   37          0.1                    5.1
#
#    Gen_Bear2_Temp_Avg  Nac_Direction_Avg
# 0                  38              206.9
# 1                  38              206.9
# 2                  38              206.9
# 3                  38              206.9
# 4                  35              207.4
#
# [5 rows x 61 columns]

# %%
t11_df = master_df[master_df["Turbine_ID"] == "T11"]

# %%
t11_df.head()
# Out:
#   Turbine_ID    times_stamp  Gen_RPM_Max  Gen_RPM_Min  Gen_RPM_Avg  \
# 0        T11  1/1/2016 0:00       1339.4       1233.3       1270.9
# 1        T11  1/1/2016 0:10       1400.5       1239.8       1303.6
# 2        T11  1/1/2016 0:20       1423.6       1270.8       1344.3
# 3        T11  1/1/2016 0:30       1470.1       1258.7       1377.5
# 6        T11  1/1/2016 0:40       1539.1       1252.1       1396.2
#
#    Gen_RPM_Std  Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# 0         18.8                 42                   59                   61
# 1         40.2                 43                   59                   61
# 2         27.2                 43                   60                   61
# 3         48.9                 43                   60                   62
# 6         66.8                 43                   61                   62
#
#    Gen_Phase3_Temp_Avg  ...  Grd_Prod_VoltPhse3_Avg  Grd_Prod_CurPhse1_Avg  \
# 0                   60  ...                   398.0                  197.0
# 1                   60  ...                   397.9                  245.0
# 2                   61  ...                   397.3                  292.3
# 3                   61  ...                   397.0                  374.6
# 6                   61  ...                   396.6                  327.7
#
#    Grd_Prod_CurPhse2_Avg  Grd_Prod_CurPhse3_Avg  Grd_Prod_Pwr_Max  \
# 0                  234.1                  216.9             368.9
# 1                  283.3                  267.2             430.4
# 2                  331.9                  317.9             468.3
# 3                  414.7                  401.7             581.2
# 6                  367.0                  351.2             641.9
#
#    Grd_Busbar_Temp_Avg  Rtr_RPM_Std  Amb_WindSpeed_Est_Avg  \
# 0                   39          0.2                    5.4
# 1                   39          0.4                    5.8
# 2                   39          0.2                    6.1
# 3                   39          0.4                    6.5
# 6                   40          0.6                    6.3
#
#    Gen_Bear2_Temp_Avg  Nac_Direction_Avg
# 0                  38              206.9
# 1                  38              206.9
# 2                  38              206.9
# 3                  38              206.9
# 6                  39              206.9
#
# [5 rows x 61 columns]

# %%
import plotly.express as px

fig = px.line(t11_df, x='times_stamp', y="Gen_RPM_Max")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\IPBri\OneDrive\Desktop\DataClass\Wind_Turbine_Reliability_Analysis\Isaac_repo\supervised_test.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/Isaac_repo/supervised_test.ipynb#ch0000004?line=0'>1</a> import plotly.express as px
#       <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/Isaac_repo/supervised_test.ipynb#ch0000004?line=2'>3</a> fig = px.line(t11_df, x='times_stamp', y="Gen_RPM_Max")
#       <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/Isaac_repo/supervised_test.ipynb#ch0000004?line=3'>4</a> fig.show()
#
# ModuleNotFoundError: No module named 'plotly'
