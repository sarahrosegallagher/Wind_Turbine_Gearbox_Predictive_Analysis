# %%
import pandas as pd

# %%
# read in the data set
df = pd.read_csv('Resources/EDPR.csv')
df.head()
# Out:
#   Turbine_ID    times_stamp  Gen_RPM_Max  Gen_RPM_Min  Gen_RPM_Avg  \
# 0        T11  1/1/2016 0:00       1339.4       1233.3       1270.9
# 1        T11  1/1/2016 0:10       1400.5       1239.8       1303.6
# 2        T11  1/1/2016 0:20       1423.6       1270.8       1344.3
# 3        T11  1/1/2016 0:30       1470.1       1258.7       1377.5
# 4        T06  1/1/2016 0:40       1302.7       1225.1       1257.6
#
#    Gen_RPM_Std  Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  Gen_Phase2_Temp_Avg  \
# 0         18.8                 42                   59                   61
# 1         40.2                 43                   59                   61
# 2         27.2                 43                   60                   61
# 3         48.9                 43                   60                   62
# 4         13.4                 41                   50                   50
#
#    Gen_Phase3_Temp_Avg  ...  Grd_Prod_VoltPhse3_Avg  Grd_Prod_CurPhse1_Avg  \
# ...

# %%
t11_df = df[df['Turbine_ID'] == "T11"]
t11_df.head(20)
# Out:
#    Turbine_ID    times_stamp  Gen_RPM_Max  Gen_RPM_Min  Gen_RPM_Avg  \
# 0         T11  1/1/2016 0:00       1339.4       1233.3       1270.9
# 1         T11  1/1/2016 0:10       1400.5       1239.8       1303.6
# 2         T11  1/1/2016 0:20       1423.6       1270.8       1344.3
# 3         T11  1/1/2016 0:30       1470.1       1258.7       1377.5
# 6         T11  1/1/2016 0:40       1539.1       1252.1       1396.2
# 10        T11  1/1/2016 0:50       1492.1       1258.0       1363.7
# 13        T11  1/1/2016 1:00       1401.2       1238.4       1280.6
# 15        T11  1/1/2016 1:10       1293.3       1235.6       1257.1
# 17        T11  1/1/2016 1:20       1311.8       1231.4       1268.8
# 20        T11  1/1/2016 6:40       1347.8       1229.2       1273.1
# 21        T11  1/1/2016 6:50       1357.7       1242.6       1289.9
# 22        T11  1/1/2016 7:00       1381.1       1246.1       1287.6
# 23        T11  1/1/2016 7:10       1292.1       1237.5       1260.5
# ...
