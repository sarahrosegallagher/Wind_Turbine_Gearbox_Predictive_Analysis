# %%
import pandas as pd

# %%
df = pd.read_csv("Dataframes/random_forest_feature_imp.csv", header=None, names=["Measurement","Feature", "Blank"])

# %%
df
# Out:
#                 Measurement                          Feature  Blank
# 0      (0.13120744311726662           'blds_pitchangle_avg')    NaN
# 1       (0.0953842837056678                   'rtr_rpm_avg')    NaN
# 2      (0.07382429081505461                   'gen_rpm_avg')    NaN
# 3     (0.049751664353657306         'grd_prod_curphse2_avg')    NaN
# 4      (0.03626276818320807                  'nac_temp_avg')    NaN
# 5      (0.03487899932700353             'gear_oil_temp_avg')    NaN
# 6      (0.03214887076663625         'gen_slipring_temp_avg')    NaN
# 7      (0.03102904805013762         'grd_prod_curphse3_avg')    NaN
# 8      (0.03068987659888469                  'amb_temp_avg')    NaN
# 9     (0.029094168274034757         'grd_prod_curphse1_avg')    NaN
# 10    (0.024841226947870502       'hvtrafo_phase2_temp_avg')    NaN
# 11     (0.02253772592066082                 'spin_temp_avg')    NaN
# 12    (0.021639234565880225             'cont_top_temp_avg')    NaN
# ...

# %%
df = df.drop(columns=["Blank"])

# %%
df
# Out:
#                 Measurement                          Feature
# 0      (0.13120744311726662           'blds_pitchangle_avg')
# 1       (0.0953842837056678                   'rtr_rpm_avg')
# 2      (0.07382429081505461                   'gen_rpm_avg')
# 3     (0.049751664353657306         'grd_prod_curphse2_avg')
# 4      (0.03626276818320807                  'nac_temp_avg')
# 5      (0.03487899932700353             'gear_oil_temp_avg')
# 6      (0.03214887076663625         'gen_slipring_temp_avg')
# 7      (0.03102904805013762         'grd_prod_curphse3_avg')
# 8      (0.03068987659888469                  'amb_temp_avg')
# 9     (0.029094168274034757         'grd_prod_curphse1_avg')
# 10    (0.024841226947870502       'hvtrafo_phase2_temp_avg')
# 11     (0.02253772592066082                 'spin_temp_avg')
# 12    (0.021639234565880225             'cont_top_temp_avg')
# 13    (0.021544686114539052             'nac_direction_avg')
# ...

# %%
# df = df.set_index(df["Feature"]).drop(columns=["Feature"])

# %%
df["Feature"]=df["Feature"].str.replace(")","")
# Out:
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df["Measurement"] = df["Measurement"].str.replace("(","")
# Out:
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Measurement    object
# Feature        object
# dtype: object

# %%
df.astype({'Measurement': 'float'}).dtypes
# Out:
# Measurement    float64
# Feature         object
# dtype: object

# %%
df.astype({'Feature': 'string'}).dtypes
# Out:
# Measurement    object
# Feature        string
# dtype: object

# %%
df = df.reindex(columns=["Feature","Measurement"])

# %%
df
# Out:
#                            Feature             Measurement
# 0            'blds_pitchangle_avg'     0.13120744311726662
# 1                    'rtr_rpm_avg'      0.0953842837056678
# 2                    'gen_rpm_avg'     0.07382429081505461
# 3          'grd_prod_curphse2_avg'    0.049751664353657306
# 4                   'nac_temp_avg'     0.03626276818320807
# 5              'gear_oil_temp_avg'     0.03487899932700353
# 6          'gen_slipring_temp_avg'     0.03214887076663625
# 7          'grd_prod_curphse3_avg'     0.03102904805013762
# 8                   'amb_temp_avg'     0.03068987659888469
# 9          'grd_prod_curphse1_avg'    0.029094168274034757
# 10       'hvtrafo_phase2_temp_avg'    0.024841226947870502
# 11                 'spin_temp_avg'     0.02253772592066082
# 12             'cont_top_temp_avg'    0.021639234565880225
# 13             'nac_direction_avg'    0.021544686114539052
# 14           'gen_phase1_temp_avg'     0.02020854439208015
# ...

# %%
df.to_csv("Dataframes/clean_random_forest_feature_imp.csv")
