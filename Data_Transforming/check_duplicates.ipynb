# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/EDPR_main.csv")

# %%
df
# Out:
#              times_stamp Turbine_ID  Grd_Prod_Pwr_Avg  Amb_WindSpeed_Avg  \
# 0          1/1/2016 0:00        T11             246.1                5.3
# 1          1/1/2016 0:10        T11             304.7                5.7
# 2          1/1/2016 0:20        T11             364.2                6.1
# 3          1/1/2016 0:30        T11             465.0                6.3
# 4          1/1/2016 0:40        T06             196.6                4.9
# ...                  ...        ...               ...                ...
# 227872  12/31/2017 23:40        T11             288.2                5.4
# 227873  12/31/2017 23:50        T06             182.8                4.7
# 227874  12/31/2017 23:50        T07             262.4                5.3
# 227875  12/31/2017 23:50        T01             242.6                5.4
# 227876  12/31/2017 23:50        T11             300.7                5.5
#
#        Susepct  wind bucket  Amb_Temp_Avg  Amb_WindDir_Abs_Avg  \
# ...

# %%
T11_df = df.loc[df["Turbine_ID"]=="T11"]

# %%
T11_df
# Out:
#              times_stamp Turbine_ID  Grd_Prod_Pwr_Avg  Amb_WindSpeed_Avg  \
# 0          1/1/2016 0:00        T11             246.1                5.3
# 1          1/1/2016 0:10        T11             304.7                5.7
# 2          1/1/2016 0:20        T11             364.2                6.1
# 3          1/1/2016 0:30        T11             465.0                6.3
# 6          1/1/2016 0:40        T11             404.6                6.4
# ...                  ...        ...               ...                ...
# 227857  12/31/2017 23:10        T11             391.5                5.8
# 227861  12/31/2017 23:20        T11             261.5                5.2
# 227865  12/31/2017 23:30        T11             191.2                4.8
# 227872  12/31/2017 23:40        T11             288.2                5.4
# 227876  12/31/2017 23:50        T11             300.7                5.5
#
#        Susepct  wind bucket  Amb_Temp_Avg  Amb_WindDir_Abs_Avg  \
# ...

# %%
df["Turbine_ID"].value_counts()
# Out:
# T11    58979
# T07    57553
# T01    56002
# T06    55343
# Name: Turbine_ID, dtype: int64

# %%
T11_df.duplicated(subset=['times_stamp']).value_counts()
# Out:
# False    58967
# True        12
# dtype: int64

# %%
T06_df = df.loc[df["Turbine_ID"]=="T06"]
T06_df.duplicated(subset=['times_stamp']).value_counts()
# Out:
# False    55331
# True        12
# dtype: int64

# %%
T07_df = df.loc[df["Turbine_ID"]=="T07"]
T07_df.duplicated(subset=['times_stamp']).value_counts()
# Out:
# False    57541
# True        12
# dtype: int64

# %%
T01_df = df.loc[df["Turbine_ID"]=="T01"]
T01_df.duplicated(subset=['times_stamp']).value_counts()
# Out:
# False    55990
# True        12
# dtype: int64
