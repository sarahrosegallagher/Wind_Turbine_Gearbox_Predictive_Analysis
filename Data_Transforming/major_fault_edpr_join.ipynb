# %%
import pandas as pd

# %%
full_df = pd.read_csv("../Resources/EDPR_1.csv")

# %%
fault_df = pd.read_csv("../Resources/Major_Faults_1.csv")

# %%
full_df.drop(columns=["Unnamed: 0"], inplace=True)
fault_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
full_df
# Out:
#                  time_stamp turbine_id  amb_temp_avg  amb_winddir_abs_avg  \
# 0       2016-01-01 00:00:00        T11            18                199.1
# 1       2016-01-01 00:10:00        T11            18                207.5
# 2       2016-01-01 00:20:00        T11            18                190.5
# 3       2016-01-01 00:30:00        T11            18                214.6
# 4       2016-01-01 00:40:00        T06            18                197.6
# ...                     ...        ...           ...                  ...
# 227872  2017-12-31 23:40:00        T11            15                328.1
# 227873  2017-12-31 23:50:00        T06            15                325.1
# 227874  2017-12-31 23:50:00        T07            15                337.7
# 227875  2017-12-31 23:50:00        T01            15                349.0
# 227876  2017-12-31 23:50:00        T11            15                333.8
#
#         amb_winddir_relative_avg  amb_windspeed_avg  blds_pitchangle_avg  \
# ...

# %%
fault_df
# Out:
#              time_stamp turbine_id              fault  \
# 0   2017-08-11 13:10:00        T01        TRANSFORMER
# 1   2017-10-17 08:40:00        T06            GEARBOX
# 2   2017-08-19 09:50:00        T06    HYDRAULIC_GROUP
# 3   2017-08-20 06:10:00        T07  GENERATOR_BEARING
# 4   2017-08-21 14:50:00        T07          GENERATOR
# 5   2017-06-17 11:40:00        T07    HYDRAULIC_GROUP
# 6   2017-10-19 10:10:00        T07    HYDRAULIC_GROUP
# 7   2017-04-26 18:10:00        T11    HYDRAULIC_GROUP
# 8   2017-09-12 15:30:00        T11    HYDRAULIC_GROUP
# 9   2016-07-18 02:10:00        T01            GEARBOX
# 10  2016-07-11 19:50:00        T06          GENERATOR
# 11  2016-07-24 17:00:00        T06          GENERATOR
# 12  2016-09-04 08:10:00        T06          GENERATOR
# 13  2016-10-27 16:30:00        T06          GENERATOR
# 14  2016-10-02 17:10:00        T06          GENERATOR
# 15  2016-04-04 18:50:00        T06    HYDRAULIC_GROUP
# ...

# %%
full_df.shape
# Out:
# (227877, 43)

# %%
#join

merged_df = pd.merge(full_df, fault_df,how="outer")

# %%
merged_df.shape
# Out:
# (227884, 45)

# %%
merged_df
# Out:
#                  time_stamp turbine_id  amb_temp_avg  amb_winddir_abs_avg  \
# 0       2016-01-01 00:00:00        T11          18.0                199.1
# 1       2016-01-01 00:10:00        T11          18.0                207.5
# 2       2016-01-01 00:20:00        T11          18.0                190.5
# 3       2016-01-01 00:30:00        T11          18.0                214.6
# 4       2016-01-01 00:40:00        T06          18.0                197.6
# ...                     ...        ...           ...                  ...
# 227879  2017-09-12 15:30:00        T11           NaN                  NaN
# 227880  2016-07-11 19:50:00        T06           NaN                  NaN
# 227881  2016-04-30 12:40:00        T07           NaN                  NaN
# 227882  2016-03-03 19:00:00        T11           NaN                  NaN
# 227883  2016-10-17 17:40:00        T11           NaN                  NaN
#
#         amb_winddir_relative_avg  amb_windspeed_avg  blds_pitchangle_avg  \
# ...

# %% [markdown]
# Note: there are 14 major faults that merged in line with measurements, there are 7 major faults that did not find a match in an existing measurement. So 7 faults have NaN for all measurements - does this cause an issue?

# %%
# explore non matching faults 
# merged_df.loc[0]["2016-04-30 12:40:00"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2016-04-30 12:40:00'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# map 0/1 for fault/no fault
# * pull column to series
# * not null as int
# * put series into fault column, drop description

# %%
fault_series = merged_df["fault"]

# %%
fault_series = fault_series.notnull().astype("int")

# %%
fault_series
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 227879    1
# 227880    1
# 227881    1
# 227882    1
# 227883    1
# Name: fault, Length: 227884, dtype: int32

# %%
merged_df["fault"] = fault_series

# %%
merged_df.drop(columns="description", inplace=True)

# %%
merged_df
# Out:
#                  time_stamp turbine_id  amb_temp_avg  amb_winddir_abs_avg  \
# 0       2016-01-01 00:00:00        T11          18.0                199.1
# 1       2016-01-01 00:10:00        T11          18.0                207.5
# 2       2016-01-01 00:20:00        T11          18.0                190.5
# 3       2016-01-01 00:30:00        T11          18.0                214.6
# 4       2016-01-01 00:40:00        T06          18.0                197.6
# ...                     ...        ...           ...                  ...
# 227879  2017-09-12 15:30:00        T11           NaN                  NaN
# 227880  2016-07-11 19:50:00        T06           NaN                  NaN
# 227881  2016-04-30 12:40:00        T07           NaN                  NaN
# 227882  2016-03-03 19:00:00        T11           NaN                  NaN
# 227883  2016-10-17 17:40:00        T11           NaN                  NaN
#
#         amb_winddir_relative_avg  amb_windspeed_avg  blds_pitchangle_avg  \
# ...

# %% [markdown]
# To CSV, To RDS

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:password@wind-turbine-analysis.chv2nnusygyy.us-west-1.rds.amazonaws.com:5432/wind_turbine_analysis")

# %%
merged_df.to_sql("merged_major_main", engine)
