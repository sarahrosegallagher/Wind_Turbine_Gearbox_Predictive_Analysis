# %%
import pandas as pd

# %%
full_df = pd.read_csv("..\Resources\EDPR.csv")
full_df
# Out:
#         Unnamed: 0          Time_Stamp Turbine_ID  Amb_Temp_Avg  \
# 0                0  01 /01 /2016 00:00        T11            18
# 1                1  01 /01 /2016 00:10        T11            18
# 2                2  01 /01 /2016 00:20        T11            18
# 3                3  01 /01 /2016 00:30        T11            18
# 4                4  01 /01 /2016 00:40        T06            18
# ...            ...                 ...        ...           ...
# 227872      227872  12 /31 /2017 23:40        T11            15
# 227873      227873  12 /31 /2017 23:50        T06            15
# 227874      227874  12 /31 /2017 23:50        T07            15
# 227875      227875  12 /31 /2017 23:50        T01            15
# 227876      227876  12 /31 /2017 23:50        T11            15
#
#         Amb_WindDir_Abs_Avg  Amb_WindDir_Relative_Avg  Amb_WindSpeed_Avg  \
# 0                     199.1                      -7.8                5.3
# 1                     207.5                       0.6                5.7
# 2                     190.5                     -16.5                6.1
# 3                     214.6                       7.6                6.3
# 4                     197.6                      -9.8                4.9
# ...                     ...                       ...                ...
# 227872                328.1                       0.0                5.4
# 227873                325.1                       0.0                4.7
# 227874                337.7                       2.9                5.3
# 227875                349.0                       1.2                5.4
# 227876                333.8                       2.4                5.5
#
#         Blds_PitchAngle_Avg  Cont_Hub_Temp_Avg  Cont_Top_Temp_Avg  ...  \
# 0                      -1.4                 28                 41  ...
# 1                      -1.7                 28                 41  ...
# 2                      -1.9                 28                 41  ...
# 3                      -2.0                 28                 41  ...
# 4                      -1.1                 27                 38  ...
# ...                     ...                ...                ...  ...
# 227872                 -1.5                 25                 38  ...
# 227873                 -1.0                 26                 30  ...
# 227874                 -1.5                 25                 26  ...
# 227875                 -1.6                 25                 37  ...
# 227876                 -1.6                 25                 38  ...
#
#         HVTrafo_Phase1_Temp_Avg  HVTrafo_Phase2_Temp_Avg  \
# 0                            46                       51
# 1                            46                       51
# 2                            46                       52
# 3                            47                       52
# 4                            45                       48
# ...                         ...                      ...
# 227872                       46                       51
# 227873                       45                       49
# 227874                       71                       73
# 227875                       64                       71
# 227876                       46                       51
#
#         HVTrafo_Phase3_Temp_Avg  Hyd_Oil_Temp_Avg  Nac_Direction_Avg  \
# 0                            46                30              206.9
# 1                            46                30              206.9
# 2                            46                30              206.9
# 3                            47                30              206.9
# 4                            45                31              207.4
# ...                         ...               ...                ...
# 227872                       46                28              328.2
# 227873                       45                28              325.1
# 227874                       71                30              334.8
# 227875                       64                26              347.8
# 227876                       46                28              331.5
#
#         Nac_Temp_Avg  Rtr_RPM_Avg  Spin_Temp_Avg  Suspect  Wind_Bucket
# 0                 27         11.3             20      0.0            5
# 1                 27         11.5             20      0.0            6
# 2                 27         11.9             20      0.0            6
# 3                 27         12.2             20      0.0            6
# 4                 29         11.1             20      0.0            5
# ...              ...          ...            ...      ...          ...
# 227872            23         11.2             17      0.0            5
# 227873            23         11.1             18      0.0            5
# 227874            21         11.1             17      0.0            5
# 227875            25         11.1             17      0.0            5
# 227876            23         11.2             17      0.0            6
#
# [227877 rows x 44 columns]

# %%
full_df.columns
# Out:
# Index(['Unnamed: 0', 'Time_Stamp', 'Turbine_ID', 'Amb_Temp_Avg',
#        'Amb_WindDir_Abs_Avg', 'Amb_WindDir_Relative_Avg', 'Amb_WindSpeed_Avg',
#        'Blds_PitchAngle_Avg', 'Cont_Hub_Temp_Avg', 'Cont_Top_Temp_Avg',
#        'Cont_VCP_ChokcoilTemp_Avg', 'Cont_VCP_Temp_Avg',
#        'Cont_VCP_WtrTemp_Avg', 'Gear_Bear_Temp_Avg', 'Gear_Oil_Temp_Avg',
#        'Gen_Bear2_Temp_Avg', 'Gen_Bear_Temp_Avg', 'Gen_Phase1_Temp_Avg',
#        'Gen_Phase2_Temp_Avg', 'Gen_Phase3_Temp_Avg', 'Gen_RPM_Avg',
#        'Gen_SlipRing_Temp_Avg', 'Grd_Busbar_Temp_Avg',
#        'Grd_InverterPhase1_Temp_Avg', 'Grd_Prod_CurPhse1_Avg',
#        'Grd_Prod_CurPhse2_Avg', 'Grd_Prod_CurPhse3_Avg', 'Grd_Prod_Pwr_Avg',
#        'Grd_Prod_VoltPhse1_Avg', 'Grd_Prod_VoltPhse2_Avg',
#        'Grd_Prod_VoltPhse3_Avg', 'Grd_RtrInvPhase1_Temp_Avg',
#        'Grd_RtrInvPhase2_Temp_Avg', 'Grd_RtrInvPhase3_Temp_Avg',
#        'HVTrafo_Phase1_Temp_Avg', 'HVTrafo_Phase2_Temp_Avg',
#        'HVTrafo_Phase3_Temp_Avg', 'Hyd_Oil_Temp_Avg', 'Nac_Direction_Avg',
#        'Nac_Temp_Avg', 'Rtr_RPM_Avg', 'Spin_Temp_Avg', 'Suspect',
#        'Wind_Bucket'],
#       dtype='object')

# %%
full_df[full_df["Susepct"] == "bad"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Susepct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_96372/306561483.py in <module>
# ----> 1 full_df[full_df["Susepct"] == "bad"]
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\sarah\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Susepct'

# %%
Suspect = full_df["Susepct"]

# %%
Suspect = Suspect.map({"bad": 1})

# %%
full_df["Susepct"] = Suspect

# %%
full_df["Susepct"] = full_df["Susepct"].fillna(0)

# %%
full_df = full_df.rename(columns={"times_stamp":"Times_Stamp","Susepct":"Suspect", "wind bucket": "Wind_Bucket"})

# %%
full_df["Time_Stamp"] = full_df["Time_Stamp"].apply(pd.to_datetime)

# full_df["Times_Stamp"] = full_df["Times_Stamp"].dt.strftime('%m /%d /%Y %H:%M')

# %%
column_names_alph = ['Times_Stamp','Turbine_ID','Amb_Temp_Avg','Amb_WindDir_Abs_Avg',
'Amb_WindDir_Relative_Avg','Amb_WindSpeed_Avg','Blds_PitchAngle_Avg','Cont_Hub_Temp_Avg','Cont_Top_Temp_Avg',
'Cont_VCP_ChokcoilTemp_Avg','Cont_VCP_Temp_Avg','Cont_VCP_WtrTemp_Avg','Gear_Bear_Temp_Avg',
'Gear_Oil_Temp_Avg','Gen_Bear2_Temp_Avg','Gen_Bear_Temp_Avg','Gen_Phase1_Temp_Avg',
'Gen_Phase2_Temp_Avg','Gen_Phase3_Temp_Avg','Gen_RPM_Avg','Gen_SlipRing_Temp_Avg',
'Grd_Busbar_Temp_Avg','Grd_InverterPhase1_Temp_Avg','Grd_Prod_CurPhse1_Avg','Grd_Prod_CurPhse2_Avg',
'Grd_Prod_CurPhse3_Avg','Grd_Prod_Pwr_Avg','Grd_Prod_VoltPhse1_Avg','Grd_Prod_VoltPhse2_Avg',
'Grd_Prod_VoltPhse3_Avg','Grd_RtrInvPhase1_Temp_Avg','Grd_RtrInvPhase2_Temp_Avg',
'Grd_RtrInvPhase3_Temp_Avg','HVTrafo_Phase1_Temp_Avg','HVTrafo_Phase2_Temp_Avg',
'HVTrafo_Phase3_Temp_Avg','Hyd_Oil_Temp_Avg','Nac_Direction_Avg',
'Nac_Temp_Avg','Rtr_RPM_Avg','Spin_Temp_Avg','Suspect','Wind_Bucket']

# %%
full_df
# Out:
#         Unnamed: 0          Time_Stamp Turbine_ID  Amb_Temp_Avg  \
# 0                0 2016-01-01 00:00:00        T11            18
# 1                1 2016-01-01 00:10:00        T11            18
# 2                2 2016-01-01 00:20:00        T11            18
# 3                3 2016-01-01 00:30:00        T11            18
# 4                4 2016-01-01 00:40:00        T06            18
# ...            ...                 ...        ...           ...
# 227872      227872 2017-12-31 23:40:00        T11            15
# 227873      227873 2017-12-31 23:50:00        T06            15
# 227874      227874 2017-12-31 23:50:00        T07            15
# 227875      227875 2017-12-31 23:50:00        T01            15
# 227876      227876 2017-12-31 23:50:00        T11            15
#
#         Amb_WindDir_Abs_Avg  Amb_WindDir_Relative_Avg  Amb_WindSpeed_Avg  \
# 0                     199.1                      -7.8                5.3
# 1                     207.5                       0.6                5.7
# 2                     190.5                     -16.5                6.1
# 3                     214.6                       7.6                6.3
# 4                     197.6                      -9.8                4.9
# ...                     ...                       ...                ...
# 227872                328.1                       0.0                5.4
# 227873                325.1                       0.0                4.7
# 227874                337.7                       2.9                5.3
# 227875                349.0                       1.2                5.4
# 227876                333.8                       2.4                5.5
#
#         Blds_PitchAngle_Avg  Cont_Hub_Temp_Avg  Cont_Top_Temp_Avg  ...  \
# 0                      -1.4                 28                 41  ...
# 1                      -1.7                 28                 41  ...
# 2                      -1.9                 28                 41  ...
# 3                      -2.0                 28                 41  ...
# 4                      -1.1                 27                 38  ...
# ...                     ...                ...                ...  ...
# 227872                 -1.5                 25                 38  ...
# 227873                 -1.0                 26                 30  ...
# 227874                 -1.5                 25                 26  ...
# 227875                 -1.6                 25                 37  ...
# 227876                 -1.6                 25                 38  ...
#
#         HVTrafo_Phase1_Temp_Avg  HVTrafo_Phase2_Temp_Avg  \
# 0                            46                       51
# 1                            46                       51
# 2                            46                       52
# 3                            47                       52
# 4                            45                       48
# ...                         ...                      ...
# 227872                       46                       51
# 227873                       45                       49
# 227874                       71                       73
# 227875                       64                       71
# 227876                       46                       51
#
#         HVTrafo_Phase3_Temp_Avg  Hyd_Oil_Temp_Avg  Nac_Direction_Avg  \
# 0                            46                30              206.9
# 1                            46                30              206.9
# 2                            46                30              206.9
# 3                            47                30              206.9
# 4                            45                31              207.4
# ...                         ...               ...                ...
# 227872                       46                28              328.2
# 227873                       45                28              325.1
# 227874                       71                30              334.8
# 227875                       64                26              347.8
# 227876                       46                28              331.5
#
#         Nac_Temp_Avg  Rtr_RPM_Avg  Spin_Temp_Avg  Suspect  Wind_Bucket
# 0                 27         11.3             20      0.0            5
# 1                 27         11.5             20      0.0            6
# 2                 27         11.9             20      0.0            6
# 3                 27         12.2             20      0.0            6
# 4                 29         11.1             20      0.0            5
# ...              ...          ...            ...      ...          ...
# 227872            23         11.2             17      0.0            5
# 227873            23         11.1             18      0.0            5
# 227874            21         11.1             17      0.0            5
# 227875            25         11.1             17      0.0            5
# 227876            23         11.2             17      0.0            6
#
# [227877 rows x 44 columns]

# %%
#lowercase column names for sql query
full_df.columns = full_df.columns.str.lower()

# %%
full_df
# Out:
#                 time_stamp turbine_id  amb_temp_avg  amb_winddir_abs_avg  \
# 0      2016-01-01 00:00:00        T11            18                199.1
# 1      2016-01-01 00:10:00        T11            18                207.5
# 2      2016-01-01 00:20:00        T11            18                190.5
# 3      2016-01-01 00:30:00        T11            18                214.6
# 4      2016-01-01 00:40:00        T06            18                197.6
# ...                    ...        ...           ...                  ...
# 227872 2017-12-31 23:40:00        T11            15                328.1
# 227873 2017-12-31 23:50:00        T06            15                325.1
# 227874 2017-12-31 23:50:00        T07            15                337.7
# 227875 2017-12-31 23:50:00        T01            15                349.0
# 227876 2017-12-31 23:50:00        T11            15                333.8
#
#         amb_winddir_relative_avg  amb_windspeed_avg  blds_pitchangle_avg  \
# 0                           -7.8                5.3                 -1.4
# 1                            0.6                5.7                 -1.7
# 2                          -16.5                6.1                 -1.9
# 3                            7.6                6.3                 -2.0
# 4                           -9.8                4.9                 -1.1
# ...                          ...                ...                  ...
# 227872                       0.0                5.4                 -1.5
# 227873                       0.0                4.7                 -1.0
# 227874                       2.9                5.3                 -1.5
# 227875                       1.2                5.4                 -1.6
# 227876                       2.4                5.5                 -1.6
#
#         cont_hub_temp_avg  cont_top_temp_avg  cont_vcp_chokcoiltemp_avg  ...  \
# 0                      28                 41                         90  ...
# 1                      28                 41                         90  ...
# 2                      28                 41                         90  ...
# 3                      28                 41                         90  ...
# 4                      27                 38                         94  ...
# ...                   ...                ...                        ...  ...
# 227872                 25                 38                         89  ...
# 227873                 26                 30                        102  ...
# 227874                 25                 26                         93  ...
# 227875                 25                 37                         88  ...
# 227876                 25                 38                         89  ...
#
#         hvtrafo_phase1_temp_avg  hvtrafo_phase2_temp_avg  \
# 0                            46                       51
# 1                            46                       51
# 2                            46                       52
# 3                            47                       52
# 4                            45                       48
# ...                         ...                      ...
# 227872                       46                       51
# 227873                       45                       49
# 227874                       71                       73
# 227875                       64                       71
# 227876                       46                       51
#
#         hvtrafo_phase3_temp_avg  hyd_oil_temp_avg  nac_direction_avg  \
# 0                            46                30              206.9
# 1                            46                30              206.9
# 2                            46                30              206.9
# 3                            47                30              206.9
# 4                            45                31              207.4
# ...                         ...               ...                ...
# 227872                       46                28              328.2
# 227873                       45                28              325.1
# 227874                       71                30              334.8
# 227875                       64                26              347.8
# 227876                       46                28              331.5
#
#         nac_temp_avg  rtr_rpm_avg  spin_temp_avg  suspect  wind_bucket
# 0                 27         11.3             20      0.0            5
# 1                 27         11.5             20      0.0            6
# 2                 27         11.9             20      0.0            6
# 3                 27         12.2             20      0.0            6
# 4                 29         11.1             20      0.0            5
# ...              ...          ...            ...      ...          ...
# 227872            23         11.2             17      0.0            5
# 227873            23         11.1             18      0.0            5
# 227874            21         11.1             17      0.0            5
# 227875            25         11.1             17      0.0            5
# 227876            23         11.2             17      0.0            6
#
# [227877 rows x 43 columns]

# %%
full_df.to_csv("../Resources/EDPR_1.csv")

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:password@wind-turbine-analysis.chv2nnusygyy.us-west-1.rds.amazonaws.com:5432/wind_turbine_analysis")

# %%
#write to rds 
full_df.to_sql("main", engine)

# %% [markdown]
# Fault table to csv
#
# * problem with datetime dtype
#
# https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.round.html
#
# freq can also be a multiple of a single unit, like ‘5T’ (i.e. 5 minutes):
#
# ts.round(freq='5T')
# Timestamp('2020-03-14 15:35:00')

# %%
fault_df = pd.read_csv("../Resources/Major_Faults.csv")

# %%
fault_df
# Out:
#    Turbine_ID         Unnamed: 1                 Unnamed: 2  \
# 0         T01        TRANSFORMER  2017-08-11T13:14:00+00:00
# 1         T06            GEARBOX  2017-10-17T08:38:00+00:00
# 2         T06    HYDRAULIC_GROUP  2017-08-19T09:47:00+00:00
# 3         T07  GENERATOR_BEARING  2017-08-20T06:08:00+00:00
# 4         T07          GENERATOR  2017-08-21T14:47:00+00:00
# 5         T07    HYDRAULIC_GROUP  2017-06-17T11:35:00+00:00
# 6         T07    HYDRAULIC_GROUP  2017-10-19T10:11:00+00:00
# 7         T11    HYDRAULIC_GROUP  2017-04-26T18:06:00+00:00
# 8         T11    HYDRAULIC_GROUP  2017-09-12T15:30:00+00:00
# 9         T01            GEARBOX  2016-07-18T02:10:00+00:00
# 10        T06          GENERATOR  2016-07-11T19:48:00+00:00
# 11        T06          GENERATOR  2016-07-24T17:01:00+00:00
# 12        T06          GENERATOR  2016-09-04T08:08:00+00:00
# 13        T06          GENERATOR  2016-10-27T16:26:00+00:00
# 14        T06          GENERATOR  2016-10-02T17:08:00+00:00
# 15        T06    HYDRAULIC_GROUP  2016-04-04T18:53:00+00:00
# 16        T07  GENERATOR_BEARING  2016-04-30T12:40:00+00:00
# 17        T07        TRANSFORMER  2016-07-10T03:46:00+00:00
# 18        T07        TRANSFORMER  2016-08-23T02:21:00+00:00
# 19        T11          GENERATOR  2016-03-03T19:00:00+00:00
# 20        T11    HYDRAULIC_GROUP  2016-10-17T17:44:00+00:00
#
#                                            Unnamed: 3
# 0                             Transformer fan damaged
# 1                            Gearbox bearings damaged
# 2                                  Oil leakage in Hub
# 3                          Generator bearings damaged
# 4                                   Generator damaged
# 5                                  Oil leakage in Hub
# 6                                  Oil leakage in Hub
# 7          Hydraulic group error in the brake circuit
# 8          Hydraulic group error in the brake circuit
# 9                                Gearbox pump damaged
# 10                                 Generator replaced
# 11               Generator temperature sensor failure
# 12                   High temperature generator error
# 13                                 Generator replaced
# 14  Refrigeration system and temperature sensors i...
# 15                          Error in pitch regulation
# 16  High temperature in generator bearing (replace...
# 17                       High temperature transformer
# 18  High temperature transformer. Transformer refr...
# 19                Electric circuit error in generator
# 20         Hydraulic group error in the brake circuit

# %%
fault_df.count()
# Out:
# Turbine_ID    21
# Unnamed: 1    21
# Unnamed: 2    21
# Unnamed: 3    21
# dtype: int64

# %%
fault_df = fault_df.rename({"Unnamed: 2":"time_stamp",
                    "Turbine_ID":"turbine_id",
                    "Unnamed: 1":"fault",
                    "Unnamed: 3":"description"}, axis=1)

# %%
fault_df = fault_df[["time_stamp", "turbine_id", "fault", "description"]]

# %%
fault_df
# Out:
#                    time_stamp turbine_id              fault  \
# 0   2017-08-11T13:14:00+00:00        T01        TRANSFORMER
# 1   2017-10-17T08:38:00+00:00        T06            GEARBOX
# 2   2017-08-19T09:47:00+00:00        T06    HYDRAULIC_GROUP
# 3   2017-08-20T06:08:00+00:00        T07  GENERATOR_BEARING
# 4   2017-08-21T14:47:00+00:00        T07          GENERATOR
# 5   2017-06-17T11:35:00+00:00        T07    HYDRAULIC_GROUP
# 6   2017-10-19T10:11:00+00:00        T07    HYDRAULIC_GROUP
# 7   2017-04-26T18:06:00+00:00        T11    HYDRAULIC_GROUP
# 8   2017-09-12T15:30:00+00:00        T11    HYDRAULIC_GROUP
# 9   2016-07-18T02:10:00+00:00        T01            GEARBOX
# 10  2016-07-11T19:48:00+00:00        T06          GENERATOR
# 11  2016-07-24T17:01:00+00:00        T06          GENERATOR
# 12  2016-09-04T08:08:00+00:00        T06          GENERATOR
# 13  2016-10-27T16:26:00+00:00        T06          GENERATOR
# 14  2016-10-02T17:08:00+00:00        T06          GENERATOR
# 15  2016-04-04T18:53:00+00:00        T06    HYDRAULIC_GROUP
# 16  2016-04-30T12:40:00+00:00        T07  GENERATOR_BEARING
# 17  2016-07-10T03:46:00+00:00        T07        TRANSFORMER
# 18  2016-08-23T02:21:00+00:00        T07        TRANSFORMER
# 19  2016-03-03T19:00:00+00:00        T11          GENERATOR
# 20  2016-10-17T17:44:00+00:00        T11    HYDRAULIC_GROUP
#
#                                           description
# 0                             Transformer fan damaged
# 1                            Gearbox bearings damaged
# 2                                  Oil leakage in Hub
# 3                          Generator bearings damaged
# 4                                   Generator damaged
# 5                                  Oil leakage in Hub
# 6                                  Oil leakage in Hub
# 7          Hydraulic group error in the brake circuit
# 8          Hydraulic group error in the brake circuit
# 9                                Gearbox pump damaged
# 10                                 Generator replaced
# 11               Generator temperature sensor failure
# 12                   High temperature generator error
# 13                                 Generator replaced
# 14  Refrigeration system and temperature sensors i...
# 15                          Error in pitch regulation
# 16  High temperature in generator bearing (replace...
# 17                       High temperature transformer
# 18  High temperature transformer. Transformer refr...
# 19                Electric circuit error in generator
# 20         Hydraulic group error in the brake circuit

# %%
fault_df.dtypes
# Out:
# time_stamp     object
# turbine_id     object
# fault          object
# description    object
# dtype: object

# %%
fault_df["time_stamp"] = fault_df["time_stamp"].apply(pd.to_datetime)

# %%
fault_df.dtypes
# Out:
# time_stamp     datetime64[ns, UTC]
# turbine_id                  object
# fault                       object
# description                 object
# dtype: object

# %%
#round demo

fault_df["time_stamp"][0].round(freq="10T")
# Out:
# Timestamp('2017-08-11 13:10:00+0000', tz='UTC')

# %%
#round loop
times = fault_df["time_stamp"]
round_times = []
for i in times:
    round_times.append(i.round(freq="10T").replace(tzinfo=None))

# %%
#rounded time to df 
fault_df["time_stamp"] = round_times

# %%
# changed => both tables have datetime for time_stamp instead of strftime 
# format timestamp to match main table 
# fault_df["time_stamp"] = fault_df["time_stamp"].dt.strftime('%m /%d /%Y %H:%M')

# %%
fault_df
# Out:
#             time_stamp turbine_id              fault  \
# 0  2017-08-11 13:10:00        T01        TRANSFORMER
# 1  2017-10-17 08:40:00        T06            GEARBOX
# 2  2017-08-19 09:50:00        T06    HYDRAULIC_GROUP
# 3  2017-08-20 06:10:00        T07  GENERATOR_BEARING
# 4  2017-08-21 14:50:00        T07          GENERATOR
# 5  2017-06-17 11:40:00        T07    HYDRAULIC_GROUP
# 6  2017-10-19 10:10:00        T07    HYDRAULIC_GROUP
# 7  2017-04-26 18:10:00        T11    HYDRAULIC_GROUP
# 8  2017-09-12 15:30:00        T11    HYDRAULIC_GROUP
# 9  2016-07-18 02:10:00        T01            GEARBOX
# 10 2016-07-11 19:50:00        T06          GENERATOR
# 11 2016-07-24 17:00:00        T06          GENERATOR
# 12 2016-09-04 08:10:00        T06          GENERATOR
# 13 2016-10-27 16:30:00        T06          GENERATOR
# 14 2016-10-02 17:10:00        T06          GENERATOR
# 15 2016-04-04 18:50:00        T06    HYDRAULIC_GROUP
# 16 2016-04-30 12:40:00        T07  GENERATOR_BEARING
# 17 2016-07-10 03:50:00        T07        TRANSFORMER
# 18 2016-08-23 02:20:00        T07        TRANSFORMER
# 19 2016-03-03 19:00:00        T11          GENERATOR
# 20 2016-10-17 17:40:00        T11    HYDRAULIC_GROUP
#
#                                           description
# 0                             Transformer fan damaged
# 1                            Gearbox bearings damaged
# 2                                  Oil leakage in Hub
# 3                          Generator bearings damaged
# 4                                   Generator damaged
# 5                                  Oil leakage in Hub
# 6                                  Oil leakage in Hub
# 7          Hydraulic group error in the brake circuit
# 8          Hydraulic group error in the brake circuit
# 9                                Gearbox pump damaged
# 10                                 Generator replaced
# 11               Generator temperature sensor failure
# 12                   High temperature generator error
# 13                                 Generator replaced
# 14  Refrigeration system and temperature sensors i...
# 15                          Error in pitch regulation
# 16  High temperature in generator bearing (replace...
# 17                       High temperature transformer
# 18  High temperature transformer. Transformer refr...
# 19                Electric circuit error in generator
# 20         Hydraulic group error in the brake circuit

# %%
full_df.to_csv("../Resources/Major_Faults_1.csv")

# %%
#write to rds using same engine as main table 
fault_df.to_sql("major_faults", engine)
