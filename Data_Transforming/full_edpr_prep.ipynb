# %% [markdown]
# read in full edpr (60ish columns)

# %%
import pandas as pd

# %%
df = pd.read_csv("..\Resources\Full_EDPR_Raw.csv")
df
# Out:
#        Turbine_ID       times_stamp  Gen_RPM_Max  Gen_RPM_Min  Gen_RPM_Avg  \
# 0             T11     1/1/2016 0:00       1339.4       1233.3       1270.9
# 1             T11     1/1/2016 0:10       1400.5       1239.8       1303.6
# 2             T11     1/1/2016 0:20       1423.6       1270.8       1344.3
# 3             T11     1/1/2016 0:30       1470.1       1258.7       1377.5
# 4             T06     1/1/2016 0:40       1302.7       1225.1       1257.6
# ...           ...               ...          ...          ...          ...
# 227872        T11  12/31/2017 23:40       1421.2       1221.0       1268.9
# 227873        T06  12/31/2017 23:50       1270.8       1229.6       1249.4
# 227874        T07  12/31/2017 23:50       1329.9       1193.0       1257.6
# 227875        T01  12/31/2017 23:50       1273.1       1239.8       1250.7
# 227876        T11  12/31/2017 23:50       1320.5       1216.8       1262.0
#
#         Gen_RPM_Std  Gen_Bear_Temp_Avg  Gen_Phase1_Temp_Avg  \
# ...

# %%
df.columns
# Out:
# Index(['Turbine_ID', 'times_stamp', 'Gen_RPM_Max', 'Gen_RPM_Min',
#        'Gen_RPM_Avg', 'Gen_RPM_Std', 'Gen_Bear_Temp_Avg',
#        'Gen_Phase1_Temp_Avg', 'Gen_Phase2_Temp_Avg', 'Gen_Phase3_Temp_Avg',
#        'Hyd_Oil_Temp_Avg', 'Gear_Oil_Temp_Avg', 'Gear_Bear_Temp_Avg',
#        'Nac_Temp_Avg', 'Rtr_RPM_Max', 'Rtr_RPM_Min', 'Rtr_RPM_Avg',
#        'Amb_WindSpeed_Max', 'Amb_WindSpeed_Min', 'Amb_WindSpeed_Avg',
#        'Amb_WindSpeed_Std', 'Amb_WindDir_Relative_Avg', 'Amb_WindDir_Abs_Avg',
#        'Amb_Temp_Avg', 'Prod_LatestAvg_ActPwrGen0',
#        'Prod_LatestAvg_ActPwrGen1', 'Prod_LatestAvg_ActPwrGen2',
#        'Prod_LatestAvg_TotActPwr', 'Prod_LatestAvg_ReactPwrGen0',
#        'Prod_LatestAvg_ReactPwrGen2', 'HVTrafo_Phase1_Temp_Avg',
#        'HVTrafo_Phase2_Temp_Avg', 'HVTrafo_Phase3_Temp_Avg',
#        'Grd_InverterPhase1_Temp_Avg', 'Cont_Top_Temp_Avg', 'Cont_Hub_Temp_Avg',
#        'Cont_VCP_Temp_Avg', 'Gen_SlipRing_Temp_Avg', 'Spin_Temp_Avg',
# ...

# %%
df.dtypes
# Out:
# Turbine_ID                object
# times_stamp               object
# Gen_RPM_Max              float64
# Gen_RPM_Min              float64
# Gen_RPM_Avg              float64
#                           ...
# Grd_Busbar_Temp_Avg        int64
# Rtr_RPM_Std              float64
# Amb_WindSpeed_Est_Avg    float64
# Gen_Bear2_Temp_Avg         int64
# Nac_Direction_Avg        float64
# Length: 61, dtype: object

# %%
df["times_stamp"]  = pd.to_datetime(df["times_stamp"], errors="coerce")

# %%
df.dtypes
# Out:
# Turbine_ID                       object
# times_stamp              datetime64[ns]
# Gen_RPM_Max                     float64
# Gen_RPM_Min                     float64
# Gen_RPM_Avg                     float64
#                               ...
# Grd_Busbar_Temp_Avg               int64
# Rtr_RPM_Std                     float64
# Amb_WindSpeed_Est_Avg           float64
# Gen_Bear2_Temp_Avg                int64
# Nac_Direction_Avg               float64
# Length: 61, dtype: object

# %%
df.rename(columns = {'times_stamp':'time_stamp'}, inplace = True)

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#        turbine_id          time_stamp  gen_rpm_max  gen_rpm_min  gen_rpm_avg  \
# 0             T11 2016-01-01 00:00:00       1339.4       1233.3       1270.9
# 1             T11 2016-01-01 00:10:00       1400.5       1239.8       1303.6
# 2             T11 2016-01-01 00:20:00       1423.6       1270.8       1344.3
# 3             T11 2016-01-01 00:30:00       1470.1       1258.7       1377.5
# 4             T06 2016-01-01 00:40:00       1302.7       1225.1       1257.6
# ...           ...                 ...          ...          ...          ...
# 227872        T11 2017-12-31 23:40:00       1421.2       1221.0       1268.9
# 227873        T06 2017-12-31 23:50:00       1270.8       1229.6       1249.4
# 227874        T07 2017-12-31 23:50:00       1329.9       1193.0       1257.6
# 227875        T01 2017-12-31 23:50:00       1273.1       1239.8       1250.7
# 227876        T11 2017-12-31 23:50:00       1320.5       1216.8       1262.0
#
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:password@wind-turbine-analysis.chv2nnusygyy.us-west-1.rds.amazonaws.com:5432/wind_turbine_analysis")

# %%
df.to_sql("main_full", engine)
