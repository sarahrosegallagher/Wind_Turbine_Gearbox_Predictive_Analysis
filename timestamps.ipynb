# %%
import pandas as pd

# %%
# Attempting to reform the WTG component Active csv into a time series organized by turbine. 
wtg_component_active_df = pd.read_csv("WTG_component_Active.csv")
wtg_component_active_df.head()
# Out:
#       TimeStampLocalSystem                             Name Systemname  \
# 0  2019-10-01 00:10:00.000  Active power reference setpoint        NaN
# 1  2019-10-01 00:10:00.000              Actual active power        NaN
# 2  2019-10-01 00:10:00.000             Blade 1 actual value     Hawa01
# 3  2019-10-01 00:10:00.000             Blade 1 actual value     Hawa02
# 4  2019-10-01 00:10:00.000             Blade 1 actual value     Hawa03
#
#    Minute10Average
# 0               50
# 1               10
# 2                2
# 3                2
# 4                2

# %%
wtg_component_active_df.tail()
# Out:
#             TimeStampLocalSystem        Name Systemname  Minute10Average
# 9751523  2020-03-07 11:50:00.000  Wind speed     Hawa25                6
# 9751524  2020-03-07 11:50:00.000  Wind speed     Hawa26                5
# 9751525  2020-03-07 11:50:00.000  Wind speed     Hawa27                6
# 9751526  2020-03-07 11:50:00.000  Wind speed     Hawa28                6
# 9751527  2020-03-07 11:50:00.000  Wind speed     Hawa29                6

# %%
wtg_component_active_df.dtypes
# Out:
# TimeStampLocalSystem    object
# Name                    object
# Systemname              object
# Minute10Average          int64
# dtype: object

# %%
wtg_component_active_df['TimeStampLocalSystem'] = pd.to_datetime(wtg_component_active_df['TimeStampLocalSystem'])

# %%
wtg_component_active_df.dtypes
# Out:
# TimeStampLocalSystem    datetime64[ns]
# Name                            object
# Systemname                      object
# Minute10Average                  int64
# dtype: object

# %%
turbines = wtg_component_active_df['Systemname'].unique()
turbines
# Out:
# array([nan, 'Hawa01', 'Hawa02', 'Hawa03', 'Hawa04', 'Hawa05', 'Hawa06',
#        'Hawa07', 'Hawa08', 'Hawa09', 'Hawa10', 'Hawa11', 'Hawa12',
#        'Hawa13', 'Hawa14', 'Hawa15', 'Hawa16', 'Hawa17', 'Hawa18',
#        'Hawa19', 'Hawa20', 'Hawa21', 'Hawa22', 'Hawa23', 'Hawa24',
#        'Hawa25', 'Hawa26', 'Hawa27', 'Hawa28', 'Hawa29'], dtype=object)

# %%
readings = wtg_component_active_df['Name'].unique()
readings
# Out:
# array(['Active power reference setpoint', 'Actual active power',
#        'Blade 1 actual value', 'Blade 2 actual value A',
#        'Blade 3 actual value A',
#        'Gear oil Temperature near heating elements',
#        'Gearbox bearing Temperature  Intermediate shaft generator side  (rotor side)',
#        'Gearbox bearing Temperature High speed shaft rotor side',
#        'Gearbox bearing Temperature Intermediate shaft rotor side',
#        'Nacelle position', 'Power', 'Temp. bearing A', 'Temp. bearing B',
#        'Temp. gear box bearing', 'Temp. gearbox', 'Temp. shaft bearing',
#        'Temperature GBX Distributor', 'Wind direction', 'Wind speed'],
#       dtype=object)

# %%
timestamps = wtg_component_active_df['TimeStampLocalSystem'].unique()
len(timestamps)
# Out:
# 22853

# %%
wtg_component_active_df['Minute10Average'].loc[(wtg_component_active_df['Name'] == 'Blade 3 actual value A') & (wtg_component_active_df['Systemname'] == 'Hawa16') & (wtg_component_active_df['TimeStampLocalSystem'] == '2019-10-01T00:20:00.000000000')].values[0]
# Out:
# 2

# %%
df = wtg_component_active_df.pivot_table(index=['Systemname', 'Name'], columns='TimeStampLocalSystem', values='Minute10Average')

# %%
df.head(50)
# Out:
# TimeStampLocalSystem                                           2019-10-01 00:10:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  212.0
#            Power                                                             427.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             63.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  198.0
#            Power                                                             450.0
#            Temp. bearing A                                                    47.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  192.0
#            Power                                                             481.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             64.0
#            Temp. gearbox                                                      56.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 00:20:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  206.0
#            Power                                                             438.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             64.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  193.0
#            Power                                                             380.0
#            Temp. bearing A                                                    47.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             65.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  187.0
#            Power                                                             366.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             63.0
#            Temp. gearbox                                                      56.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          6.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 00:30:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  201.0
#            Power                                                             706.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  186.0
#            Power                                                             718.0
#            Temp. bearing A                                                    47.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             68.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  177.0
#            Power                                                             815.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 00:40:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  213.0
#            Power                                                             693.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             67.0
#            Temp. gearbox                                                      59.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  200.0
#            Power                                                             687.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  189.0
#            Power                                                             667.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             67.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 00:50:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  223.0
#            Power                                                             907.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      60.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  207.0
#            Power                                                             649.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  200.0
#            Power                                                             749.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             67.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 01:00:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  212.0
#            Power                                                             886.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      60.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  200.0
#            Power                                                            1094.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             70.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  190.0
#            Power                                                            1177.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             70.0
#            Temp. gearbox                                                      59.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 01:10:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                3.0
#            Blade 2 actual value A                                              3.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  222.0
#            Power                                                            1442.0
#            Temp. bearing A                                                    45.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             70.0
#            Temp. gearbox                                                      60.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          9.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  207.0
#            Power                                                            1209.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             71.0
#            Temp. gearbox                                                      59.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  199.0
#            Power                                                            1445.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             71.0
#            Temp. gearbox                                                      59.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          9.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 01:20:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  242.0
#            Power                                                             992.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      60.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  230.0
#            Power                                                             856.0
#            Temp. bearing A                                                    47.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             68.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  220.0
#            Power                                                             908.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             69.0
#            Temp. gearbox                                                      59.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          8.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 01:30:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  251.0
#            Power                                                             731.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  236.0
#            Power                                                             693.0
#            Temp. bearing A                                                    47.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      56.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  229.0
#            Power                                                             749.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             66.0
#            Temp. gearbox                                                      58.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           2019-10-01 01:40:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  249.0
#            Power                                                             689.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             65.0
#            Temp. gearbox                                                      57.0
#            Temp. shaft bearing                                                39.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa02     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              1.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  234.0
#            Power                                                             670.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    49.0
#            Temp. gear box bearing                                             65.0
#            Temp. gearbox                                                      55.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa03     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#            Blade 3 actual value A                                              2.0
#            Gear oil Temperature near heating elements                          0.0
#            Gearbox bearing Temperature  Intermediate shaft...                  0.0
#            Gearbox bearing Temperature High speed shaft ro...                  0.0
#            Gearbox bearing Temperature Intermediate shaft ...                  0.0
#            Nacelle position                                                  226.0
#            Power                                                             543.0
#            Temp. bearing A                                                    46.0
#            Temp. bearing B                                                    50.0
#            Temp. gear box bearing                                             64.0
#            Temp. gearbox                                                      56.0
#            Temp. shaft bearing                                                40.0
#            Temperature GBX Distributor                                         0.0
#            Wind speed                                                          7.0
# Hawa04     Blade 1 actual value                                                2.0
#            Blade 2 actual value A                                              2.0
#
# TimeStampLocalSystem                                           ...  \
# Systemname Name                                                ...
# Hawa01     Blade 1 actual value                                ...
#            Blade 2 actual value A                              ...
#            Blade 3 actual value A                              ...
#            Gear oil Temperature near heating elements          ...
#            Gearbox bearing Temperature  Intermediate shaft...  ...
#            Gearbox bearing Temperature High speed shaft ro...  ...
#            Gearbox bearing Temperature Intermediate shaft ...  ...
#            Nacelle position                                    ...
#            Power                                               ...
#            Temp. bearing A                                     ...
#            Temp. bearing B                                     ...
#            Temp. gear box bearing                              ...
#            Temp. gearbox                                       ...
#            Temp. shaft bearing                                 ...
#            Temperature GBX Distributor                         ...
#            Wind speed                                          ...
# Hawa02     Blade 1 actual value                                ...
#            Blade 2 actual value A                              ...
#            Blade 3 actual value A                              ...
#            Gear oil Temperature near heating elements          ...
#            Gearbox bearing Temperature  Intermediate shaft...  ...
#            Gearbox bearing Temperature High speed shaft ro...  ...
#            Gearbox bearing Temperature Intermediate shaft ...  ...
#            Nacelle position                                    ...
#            Power                                               ...
#            Temp. bearing A                                     ...
#            Temp. bearing B                                     ...
#            Temp. gear box bearing                              ...
#            Temp. gearbox                                       ...
#            Temp. shaft bearing                                 ...
#            Temperature GBX Distributor                         ...
#            Wind speed                                          ...
# Hawa03     Blade 1 actual value                                ...
#            Blade 2 actual value A                              ...
#            Blade 3 actual value A                              ...
#            Gear oil Temperature near heating elements          ...
#            Gearbox bearing Temperature  Intermediate shaft...  ...
#            Gearbox bearing Temperature High speed shaft ro...  ...
#            Gearbox bearing Temperature Intermediate shaft ...  ...
#            Nacelle position                                    ...
#            Power                                               ...
#            Temp. bearing A                                     ...
#            Temp. bearing B                                     ...
#            Temp. gear box bearing                              ...
# ...
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa03     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa04     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#
# TimeStampLocalSystem                                           2020-03-07 11:30:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa02     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa03     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa04     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#
# TimeStampLocalSystem                                           2020-03-07 11:40:00  \
# Systemname Name
# Hawa01     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa02     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa03     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa04     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#
# TimeStampLocalSystem                                           2020-03-07 11:50:00
# Systemname Name
# Hawa01     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa02     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa03     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#            Blade 3 actual value A                                              NaN
#            Gear oil Temperature near heating elements                          NaN
#            Gearbox bearing Temperature  Intermediate shaft...                  NaN
#            Gearbox bearing Temperature High speed shaft ro...                  NaN
#            Gearbox bearing Temperature Intermediate shaft ...                  NaN
#            Nacelle position                                                    NaN
#            Power                                                               NaN
#            Temp. bearing A                                                     NaN
#            Temp. bearing B                                                     NaN
#            Temp. gear box bearing                                              NaN
#            Temp. gearbox                                                       NaN
#            Temp. shaft bearing                                                 NaN
#            Temperature GBX Distributor                                         NaN
#            Wind speed                                                          NaN
# Hawa04     Blade 1 actual value                                                NaN
#            Blade 2 actual value A                                              NaN
#
# [50 rows x 22701 columns]

# %%
# Demonstrating selecting time series data for a particular turbine
df.loc['Hawa01']
# Out:
# TimeStampLocalSystem                                2019-10-01 00:10:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  212.0
# Power                                                             427.0
# Temp. bearing A                                                    46.0
# Temp. bearing B                                                    50.0
# Temp. gear box bearing                                             63.0
# Temp. gearbox                                                      57.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          6.0
#
# TimeStampLocalSystem                                2019-10-01 00:20:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  206.0
# Power                                                             438.0
# Temp. bearing A                                                    46.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             64.0
# Temp. gearbox                                                      57.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          6.0
#
# TimeStampLocalSystem                                2019-10-01 00:30:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  201.0
# Power                                                             706.0
# Temp. bearing A                                                    45.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             66.0
# Temp. gearbox                                                      58.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          7.0
#
# TimeStampLocalSystem                                2019-10-01 00:40:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  213.0
# Power                                                             693.0
# Temp. bearing A                                                    45.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             67.0
# Temp. gearbox                                                      59.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          7.0
#
# TimeStampLocalSystem                                2019-10-01 00:50:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  223.0
# Power                                                             907.0
# Temp. bearing A                                                    45.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             69.0
# Temp. gearbox                                                      60.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          8.0
#
# TimeStampLocalSystem                                2019-10-01 01:00:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  212.0
# Power                                                             886.0
# Temp. bearing A                                                    45.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             69.0
# Temp. gearbox                                                      60.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          7.0
#
# TimeStampLocalSystem                                2019-10-01 01:10:00  \
# Name
# Blade 1 actual value                                                3.0
# Blade 2 actual value A                                              3.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  222.0
# Power                                                            1442.0
# Temp. bearing A                                                    45.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             70.0
# Temp. gearbox                                                      60.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          9.0
#
# TimeStampLocalSystem                                2019-10-01 01:20:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  242.0
# Power                                                             992.0
# Temp. bearing A                                                    46.0
# Temp. bearing B                                                    49.0
# Temp. gear box bearing                                             69.0
# Temp. gearbox                                                      60.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          8.0
#
# TimeStampLocalSystem                                2019-10-01 01:30:00  \
# Name
# Blade 1 actual value                                                2.0
# Blade 2 actual value A                                              2.0
# Blade 3 actual value A                                              2.0
# Gear oil Temperature near heating elements                          0.0
# Gearbox bearing Temperature  Intermediate shaft...                  0.0
# Gearbox bearing Temperature High speed shaft ro...                  0.0
# Gearbox bearing Temperature Intermediate shaft ...                  0.0
# Nacelle position                                                  251.0
# Power                                                             731.0
# Temp. bearing A                                                    46.0
# Temp. bearing B                                                    50.0
# Temp. gear box bearing                                             66.0
# Temp. gearbox                                                      58.0
# Temp. shaft bearing                                                40.0
# Temperature GBX Distributor                                         0.0
# Wind speed                                                          7.0
#
# TimeStampLocalSystem                                2019-10-01 01:40:00  ...  \
# Name                                                                     ...
# Blade 1 actual value                                                2.0  ...
# Blade 2 actual value A                                              2.0  ...
# Blade 3 actual value A                                              2.0  ...
# Gear oil Temperature near heating elements                          0.0  ...
# Gearbox bearing Temperature  Intermediate shaft...                  0.0  ...
# Gearbox bearing Temperature High speed shaft ro...                  0.0  ...
# Gearbox bearing Temperature Intermediate shaft ...                  0.0  ...
# Nacelle position                                                  249.0  ...
# Power                                                             689.0  ...
# Temp. bearing A                                                    46.0  ...
# Temp. bearing B                                                    50.0  ...
# Temp. gear box bearing                                             65.0  ...
# Temp. gearbox                                                      57.0  ...
# Temp. shaft bearing                                                39.0  ...
# Temperature GBX Distributor                                         0.0  ...
# Wind speed                                                          7.0  ...
#
# TimeStampLocalSystem                                2020-03-07 10:20:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 10:30:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 10:40:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 10:50:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:00:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:10:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:20:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:30:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:40:00  \
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# TimeStampLocalSystem                                2020-03-07 11:50:00
# Name
# Blade 1 actual value                                                NaN
# Blade 2 actual value A                                              NaN
# Blade 3 actual value A                                              NaN
# Gear oil Temperature near heating elements                          NaN
# Gearbox bearing Temperature  Intermediate shaft...                  NaN
# Gearbox bearing Temperature High speed shaft ro...                  NaN
# Gearbox bearing Temperature Intermediate shaft ...                  NaN
# Nacelle position                                                    NaN
# Power                                                               NaN
# Temp. bearing A                                                     NaN
# Temp. bearing B                                                     NaN
# Temp. gear box bearing                                              NaN
# Temp. gearbox                                                       NaN
# Temp. shaft bearing                                                 NaN
# Temperature GBX Distributor                                         NaN
# Wind speed                                                          NaN
#
# [16 rows x 22701 columns]

# %%
# Demonstrating selecting a particular metric within that turbine
df.loc[('Hawa01', 'Blade 1 actual value')]
# Out:
# TimeStampLocalSystem
# 2019-10-01 00:10:00    2.0
# 2019-10-01 00:20:00    2.0
# 2019-10-01 00:30:00    2.0
# 2019-10-01 00:40:00    2.0
# 2019-10-01 00:50:00    2.0
#                       ...
# 2020-03-07 11:10:00    NaN
# 2020-03-07 11:20:00    NaN
# 2020-03-07 11:30:00    NaN
# 2020-03-07 11:40:00    NaN
# 2020-03-07 11:50:00    NaN
# Name: (Hawa01, Blade 1 actual value), Length: 22701, dtype: float64

# %%
## Deprecated code block that attempted to create above pivot table

# hawa01_timeseries = {}
# counter = 0

# for timestamp in timestamps:
#     counter =+ 1
#     print(f"processing {timestamp}, number {counter}")

#     measurements = []

#     for reading in readings: 
#         df = wtg_component_active_df[(wtg_component_active_df['Systemname'] == 'Hawa01') & (wtg_component_active_df['Name'] == reading)]
#         measurements.append(df['Minute10Average'])

#     hawa01_dict = dict(zip(readings, measurements))
#     hawa01_timeseries[timestamp] = hawa01_dict

#
# Out:
# processing 2019-10-01T00:10:00.000000000, number 1
# processing 2019-10-01T00:20:00.000000000, number 1
# processing 2019-10-01T00:30:00.000000000, number 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49508/2940547947.py in <module>
#       9
#      10     for reading in readings:
# ---> 11         df = wtg_component_active_df[(wtg_component_active_df['Systemname'] == 'Hawa01') & (wtg_component_active_df['Name'] == reading)]
#      12         measurements.append(df['Minute10Average'])
#      13
#
# c:\Users\IPBri\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\Users\IPBri\anaconda3\envs\PythonData\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# c:\Users\IPBri\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# c:\Users\IPBri\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# c:\Users\IPBri\anaconda3\envs\PythonData\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      72     else:
#      73         result = libops.scalar_compare(x.ravel(), y, op)
# ---> 74     return result.reshape(x.shape)
#      75
#      76
#
# KeyboardInterrupt:

# %%
# # Another deprecated attempt

# packets = []
# for time in timestamps: 
#     print(f"{time} processing...")

#     for turbine in turbines:
#         print(f"{turbine} processing...") 
#         measurements = []

#         for reading in readings:
#             try:
#                 measurements.append(wtg_component_active_df['Minute10Average'].loc[(wtg_component_active_df['Systemname'] == turbine) & 
#                  (wtg_component_active_df['TimeStampLocalSystem'] == time) & 
#                     (wtg_component_active_df['Name'] == reading)].values[0])
#             except IndexError:
#                 measurements.append(None)
        
#         dataPacket = dict(zip(readings, measurements))
#         packets.append(dataPacket)

#         print(dataPacket.values())
# Out:
# 2019-10-01T00:10:00.000000000 processing...
# nan processing...
# dict_values([None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None])
# Hawa01 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 212, 427, 46, 50, 63, 57, 40, 0, None, 6])
# Hawa02 processing...
# dict_values([None, None, 2, 1, 2, 0, 0, 0, 0, 198, 450, 47, 50, 66, 57, 40, 0, None, 6])
# Hawa03 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 192, 481, 46, 50, 64, 56, 40, 0, None, 6])
# Hawa04 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 196, 483, 45, 51, 65, 58, 40, 0, None, 6])
# Hawa05 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 184, 471, 44, 48, 64, 56, 40, 0, None, 5])
# Hawa06 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 189, 516, 46, 50, 65, 57, 40, 0, None, 6])
# Hawa07 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 203, 359, 45, 47, 62, 55, 40, 0, None, 6])
# Hawa08 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 222, 419, 44, 48, 64, 57, 39, 0, None, 6])
# Hawa09 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 199, 469, 44, 46, 64, 56, 39, 0, None, 7])
# Hawa10 processing...
# dict_values([None, None, 2, 1, 2, 0, 0, 0, 0, 215, 478, 45, 47, 65, 56, 39, 0, None, 7])
# Hawa11 processing...
# dict_values([None, None, 2, 2, 1, 0, 0, 0, 0, 222, 432, 43, 47, 63, 56, 40, 0, None, 6])
# Hawa12 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 196, 427, 44, 47, 63, 57, 39, 0, None, 6])
# Hawa13 processing...
# dict_values([None, None, 1, 2, 2, 0, 0, 0, 0, 208, 411, 44, 47, 62, 56, 39, 0, None, 6])
# Hawa14 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 243, 355, 43, 47, 63, 56, 40, 0, None, 6])
# Hawa15 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 206, 332, 45, 47, 63, 55, 40, 0, None, 6])
# Hawa16 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 206, 264, 43, 46, 61, 56, 39, 0, None, 5])
# Hawa17 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 198, 264, 44, 47, 62, 55, 39, 0, None, 5])
# Hawa18 processing...
# dict_values([None, None, 2, 1, 1, 0, 0, 0, 0, 196, 252, 43, 46, 62, 55, 40, 0, None, 5])
# Hawa19 processing...
# dict_values([None, None, 1, 1, 2, 0, 0, 0, 0, 198, 245, 43, 47, 61, 56, 39, 0, None, 5])
# Hawa20 processing...
# dict_values([None, None, 1, 1, 2, 0, 0, 0, 0, 211, 203, 43, 46, 62, 55, 39, 0, None, 5])
# Hawa21 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 227, 217, 43, 47, 62, 55, 39, 0, None, 5])
# Hawa22 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 201, 218, 44, 48, 64, 57, 40, 0, None, 5])
# Hawa23 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 210, 249, 43, 46, 62, 55, 39, 0, None, 5])
# Hawa24 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 210, 273, 45, 48, 63, 56, 40, 0, None, 5])
# Hawa25 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 208, 263, 43, 46, 59, 57, 39, 0, None, 5])
# Hawa26 processing...
# dict_values([None, None, 2, 1, 1, 0, 0, 0, 0, 201, 237, 43, 47, 61, 55, 39, 0, None, 5])
# Hawa27 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 231, 206, 44, 47, 60, 56, 38, 0, None, 5])
# Hawa28 processing...
# dict_values([None, None, 1, 2, 1, 0, 0, 0, 0, 227, 169, 44, 47, 62, 56, 40, 0, None, 5])
# Hawa29 processing...
# dict_values([None, None, 1, 1, 1, 0, 0, 0, 0, 215, 169, 44, 48, 61, 55, 38, 0, None, 5])
# 2019-10-01T00:20:00.000000000 processing...
# nan processing...
# dict_values([None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None])
# Hawa01 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 206, 438, 46, 49, 64, 57, 40, 0, None, 6])
# Hawa02 processing...
# dict_values([None, None, 2, 1, 2, 0, 0, 0, 0, 193, 380, 47, 49, 65, 57, 40, 0, None, 6])
# Hawa03 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 187, 366, 46, 49, 63, 56, 40, 0, None, 6])
# Hawa04 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 194, 377, 45, 50, 65, 58, 40, 0, None, 6])
# Hawa05 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 187, 389, 44, 48, 64, 56, 40, 0, None, 5])
# Hawa06 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 190, 461, 46, 49, 66, 57, 40, 0, None, 6])
# Hawa07 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 206, 394, 45, 47, 63, 55, 40, 0, None, 6])
# Hawa08 processing...
# dict_values([None, None, 2, 2, 2, 0, 0, 0, 0, 221, 387, 44, 47, 65, 57, 39, 0, None, 6])
# Hawa09 processing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\IPBri\OneDrive\Desktop\DataClass\Wind_Turbine_Reliability_Analysis\timestamps.ipynb Cell 12' in <cell line: 3>()
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=9'>10</a> for reading in readings:
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=10'>11</a>     try:
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=11'>12</a>         measurements.append(wtg_component_active_df['Minute10Average'].loc[(wtg_component_active_df['Systemname'] == turbine) &
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=12'>13</a>          (wtg_component_active_df['TimeStampLocalSystem'] == time) &
# ---> <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=13'>14</a>             (wtg_component_active_df['Name'] == reading)].values[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=14'>15</a>     except IndexError:
#      <a href='vscode-notebook-cell:/c%3A/Users/IPBri/OneDrive/Desktop/DataClass/Wind_Turbine_Reliability_Analysis/timestamps.ipynb#ch0000013?line=15'>16</a>         measurements.append(None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# -> 5623     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5625 return self._construct_result(res_values, name=res_name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\ops\array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\ops\array_ops.py:74, in comp_method_OBJECT_ARRAY(op, x, y)
#      72 else:
#      73     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 74 return result.reshape(x.shape)
#
# KeyboardInterrupt:
